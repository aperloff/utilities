# %%
import sys
# !{sys.executable} -m pip install graphviz

# %%
import dask
import distributed
import importlib.util
import multiprocessing as mp

# %%
cluster = distributed.LocalCluster(
    n_workers=int(0.6666 * mp.cpu_count())
    n_workers = 16,
    threads_per_worker = 1)
cluster
client = distributed.Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:44389' processes=16 threads=16, memory=31.25 GiB>

# %%
client.shutdown()

# %%
import AnalyzeDatasetSizes
from AnalyzeTFileSizes import Unit

# %%
import importlib
importlib.reload(AnalyzeDatasetSizes)

# %%
# %%time
ttreeinfo = AnalyzeDatasetSizes.analyze_dataset_sizes(
    "root://cmseos.fnal.gov//store/user/lpcsusyhad/SusyRA2Analysis2015/Run2ProductionV20/Summer20UL18/ZJetsToNuNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8/",
    tdirectory="TreeMaker2",
    ttree="PreSelection",
    entry_unit = Unit.KiB,
    dataset_unit = Unit.TiB,
    output = "Summer20UL18.ZJetsToNuNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8.log",
    debug = True
)
# Out:
# Running sanity checks before proceeding ... DONE
#
# Retrieving file list ... DONE
# Number of files to process: 10
#
# TTreeInfo(473394, 509, 8819914375)
# Basepath for files: root://cmseos.fnal.gov//store/user/lpcsusyhad/SusyRA2Analysis2015/Run2ProductionV20/Summer20UL18/ZJetsToNuNu_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8/
# Number of files in sample: 10Tree: TreeMaker2/PreSelection
# Entries: 473,394
# Size: 0.01 TiB (compressed)
# <Size/Entry>: 18.19 KiB (compressed)
#
# CPU times: user 1.65 s, sys: 231 ms, total: 1.88 s
# Wall time: 5.01 s
